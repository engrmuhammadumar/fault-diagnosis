# %%
# 03_model_training.ipynb

import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# Load data
X = np.load('../data/processed/X_accelerometer_looped.npy')
y = np.load('../data/processed/y_accelerometer_looped.npy')

print("Data shape:", X.shape)
print("Labels shape:", y.shape)

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_categorical = to_categorical(y_encoded)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.2, random_state=42, stratify=y_categorical)

# Add channel dimension
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# Build CNN model
model = Sequential([
    Conv1D(16, 5, activation='relu', input_shape=(X.shape[1], 1)),
    MaxPooling1D(2),
    Dropout(0.2),

    Conv1D(32, 5, activation='relu'),
    MaxPooling1D(2),
    Dropout(0.2),

    Conv1D(64, 3, activation='relu'),
    GlobalAveragePooling1D(),

    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(y_categorical.shape[1], activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# Train model
history = model.fit(X_train, y_train, epochs=30, batch_size=8, validation_split=0.1, verbose=1)

# Evaluate model
loss, acc = model.evaluate(X_test, y_test)
print(f"\n✅ Test Accuracy: {acc*100:.2f}%")

# Predictions
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Classification report
print("\nClassification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=le.classes_))

# Confusion Matrix
conf_mat = confusion_matrix(y_true_classes, y_pred_classes)

# Plot confusion matrix
import seaborn as sns
plt.figure(figsize=(8,6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()
# Out:
# Data shape: (40, 200)
# Labels shape: (40,)
# c:\Users\Muhammad Umar\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 196, 16)        │            96 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 98, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 98, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 94, 32)         │         2,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 47, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 47, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 45, 64)         │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,141 (43.52 KB)
#  Trainable params: 11,141 (43.52 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.2357 - loss: 1.6391 - val_accuracy: 0.0000e+00 - val_loss: 1.6150
# Epoch 2/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2833 - loss: 1.6043 - val_accuracy: 0.0000e+00 - val_loss: 1.6212
# Epoch 3/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2833 - loss: 1.5980 - val_accuracy: 0.0000e+00 - val_loss: 1.6433
# Epoch 4/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3083 - loss: 1.5905 - val_accuracy: 0.0000e+00 - val_loss: 1.6576
# Epoch 5/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2982 - loss: 1.5704 - val_accuracy: 0.0000e+00 - val_loss: 1.6592
# Epoch 6/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1298 - loss: 1.5899 - val_accuracy: 0.0000e+00 - val_loss: 1.6346
# Epoch 7/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3685 - loss: 1.5252 - val_accuracy: 0.0000e+00 - val_loss: 1.6402
# Epoch 8/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2851 - loss: 1.5695 - val_accuracy: 0.0000e+00 - val_loss: 1.6412
# Epoch 9/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2869 - loss: 1.5562 - val_accuracy: 0.0000e+00 - val_loss: 1.6455
# Epoch 10/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2310 - loss: 1.5609 - val_accuracy: 0.0000e+00 - val_loss: 1.6475
# Epoch 11/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3827 - loss: 1.5128 - val_accuracy: 0.0000e+00 - val_loss: 1.6498
# Epoch 12/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4482 - loss: 1.5259 - val_accuracy: 0.0000e+00 - val_loss: 1.6554
# Epoch 13/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3577 - loss: 1.4958 - val_accuracy: 0.0000e+00 - val_loss: 1.6510
# Epoch 14/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2887 - loss: 1.4871 - val_accuracy: 0.0000e+00 - val_loss: 1.6535
# Epoch 15/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3560 - loss: 1.5670 - val_accuracy: 0.2500 - val_loss: 1.6615
# Epoch 16/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2476 - loss: 1.5018 - val_accuracy: 0.0000e+00 - val_loss: 1.7051
# Epoch 17/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4649 - loss: 1.4917 - val_accuracy: 0.0000e+00 - val_loss: 1.7541
# Epoch 18/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3952 - loss: 1.4947 - val_accuracy: 0.0000e+00 - val_loss: 1.7759
# Epoch 19/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2619 - loss: 1.4906 - val_accuracy: 0.0000e+00 - val_loss: 1.7584
# Epoch 20/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5851 - loss: 1.3960 - val_accuracy: 0.0000e+00 - val_loss: 1.7359
# Epoch 21/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4256 - loss: 1.4113 - val_accuracy: 0.0000e+00 - val_loss: 1.7618
# Epoch 22/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4304 - loss: 1.5198 - val_accuracy: 0.0000e+00 - val_loss: 1.7874
# Epoch 23/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4464 - loss: 1.4245 - val_accuracy: 0.0000e+00 - val_loss: 1.7798
# Epoch 24/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4440 - loss: 1.4364 - val_accuracy: 0.0000e+00 - val_loss: 1.7837
# Epoch 25/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5458 - loss: 1.3934 - val_accuracy: 0.0000e+00 - val_loss: 1.7971
# Epoch 26/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4256 - loss: 1.4125 - val_accuracy: 0.0000e+00 - val_loss: 1.8304
# Epoch 27/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4601 - loss: 1.4244 - val_accuracy: 0.0000e+00 - val_loss: 1.8009
# Epoch 28/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4030 - loss: 1.4417 - val_accuracy: 0.0000e+00 - val_loss: 1.8000
# Epoch 29/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3452 - loss: 1.4505 - val_accuracy: 0.0000e+00 - val_loss: 1.7753
# Epoch 30/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4881 - loss: 1.3125 - val_accuracy: 0.0000e+00 - val_loss: 1.7851
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.0000e+00 - loss: 1.7206
#
# ✅ Test Accuracy: 0.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
#
# Classification Report:
#                        precision    recall  f1-score   support
#
# Circumferential Crack       0.00      0.00      0.00       1.0
#           Gasket Leak       0.00      0.00      0.00       2.0
#    Longitudinal Crack       0.00      0.00      0.00       2.0
#               No-leak       0.00      0.00      0.00       1.0
#          Orifice Leak       0.00      0.00      0.00       2.0
#
#              accuracy                           0.00       8.0
#             macro avg       0.00      0.00      0.00       8.0
#          weighted avg       0.00      0.00      0.00       8.0
# c:\Users\Muhammad Umar\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Muhammad Umar\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Muhammad Umar\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
